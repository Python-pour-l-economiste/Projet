# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# I- Selection et nettoyage des données

# %%
df_synthese = pd.read_csv("Agribalyse_Synthese.csv")
df_detail_ingredient = pd.read_csv("Agribalyse_Detail ingredient.csv")
df_détail_etape = pd.read_csv("Agribalyse_Detail etape.csv")
df_agriculture = pd.read_excel("AGRIBALYSE3_partie agriculture.xlsx", encoding ="latin")

# %%
df_synthese
# Out:
#      Code AGB  Code CIQUAL                             Groupe d'aliment  \
# 0       13712      13712.0  fruits, légumes, légumineuses et oléagineux
# 1       13713      13713.0  fruits, légumes, légumineuses et oléagineux
# 2       13714      13714.0  fruits, légumes, légumineuses et oléagineux
# 3       13715      13715.0  fruits, légumes, légumineuses et oléagineux
# 4       13000      13000.0  fruits, légumes, légumineuses et oléagineux
# ...       ...          ...                                          ...
# 2992      NaN          NaN                                          NaN
# 2993      NaN          NaN                                          NaN
# 2994      NaN          NaN                                          NaN
# 2995      NaN          NaN                                          NaN
# 2996      NaN          NaN                                          NaN
#
#      Sous-groupe d'aliment                      Nom du Produit en Français  \
# ...

# %%
df_détail_etape
# Out:
#      Code AGB  Code CIQUAL                             Groupe d'aliment  \
# 0       12112      12112.0                    lait et produits laitiers
# 1       13712      13712.0  fruits, légumes, légumineuses et oléagineux
# 2       13713      13713.0  fruits, légumes, légumineuses et oléagineux
# 3       13714      13714.0  fruits, légumes, légumineuses et oléagineux
# 4       13715      13715.0  fruits, légumes, légumineuses et oléagineux
# ...       ...          ...                                          ...
# 2991      NaN          NaN                                          NaN
# 2992      NaN          NaN                                          NaN
# 2993      NaN          NaN                                          NaN
# 2994      NaN          NaN                                          NaN
# 2995      NaN          NaN                                          NaN
#
#      Sous-groupe d'aliment                      Nom du Produit en Français  \
# ...

# %%
df_detail_ingredient
# Out:
#       Ciqual AGB  Ciqual code                            Nom Français  \
# 0          11168        11168                Sauce aïoli, préemballée
# 1          11168        11168                Sauce aïoli, préemballée
# 2          11168        11168                Sauce aïoli, préemballée
# 3          11168        11168                Sauce aïoli, préemballée
# 4          11168        11168                Sauce aïoli, préemballée
# ...          ...          ...                                     ...
# 5666       19552        19552  Yaourt à la grecque, sur lit de fruits
# 5667       19552        19552  Yaourt à la grecque, sur lit de fruits
# 5668       19860        19860             Yaourt à la grecque, nature
# 5669       19860        19860             Yaourt à la grecque, nature
# 5670       19860        19860             Yaourt à la grecque, nature
#
#                             Groupe d'aliment  \
# 0     aides culinaires et ingrédients divers
# ...

# %%
df_agriculture
# Out:
#   Les données fournies dans ce fichier ont été produites dans le cadre du projet AGRIBALYSE. Elles sont mises à disposition publiquement par les partenaires du projet, dans le cadre de la politique "openData " de l'ADEME (licence Etalab). \nCes données renseignent sur les impacts environnementaux des productions agricoles; calculées selon la méthode de l'Analyse du Cycle de Vie (ACV). La méthodologie est décrite en détail dans la documentation disponible sur le site web. Ces données sont une version simplifiée de la base de données Agribalyse, exploitable dans son intégralité avec les logiciels ACV (SimaPro, openLCA). \nCes données, à l'étape agricole (incluant les intrants agricoles et les opérations à la ferme); sont complémentaires aux données sur les produits alimentaires (incluant les étapes de transformation, logistique, emballage, préparation...) disponibles sur le site web. \n
# 0                                  www.agribalyse.fr

# %%
#sélection des pages excel qui nous intéressent
df_agriculture = pd.ExcelFile("AGRIBALYSE3_partie agriculture.xlsx")
df_agri1 = pd.read_excel(df_agriculture, "AGB_agri",header=1)
df_agri2 = pd.read_excel(df_agriculture, "AGB organic product",header=1)
df_agri1
# Out:
#                                             Unnamed: 0  \
# 0    Nom du Produit en Français (traduction approxi...
# 1          Poulet, Bleu Blanc Coeur, at farm gate/FR U
# 2           Poulet, conventionnel, départ ferme / FR U
# 3        Poulet, Label Rouge, à la  de la ferme / FR U
# 4    Poulet, moyenne nationale, à la  de la ferme /...
# ..                                                 ...
# 236  Coquille Saint-Jacques, BSBrieuc, Dredge, en m...
# 237  Hareng de l'Atlantique, NEA, Pelagic Chalut, e...
# 238  Maquereau Atlantique, NEA, Pelagic Chalut, en ...
# 239  Listao, la CEA, la Seine, en moyenne, à l'atte...
# 240  Thon Albacore, la CEA, la Seine, en moyenne, à...
#
#                                             Unnamed: 1  \
# 0                                             LCI Name
# 1         Broiler; Bleu Blanc Coeur, at farm gate/FR U
# 2             Broiler, conventional, at farm gate/FR U
# 3              Broiler, Label Rouge, at farm gate/FR U
# ...

# %%
df_agri2
# Out:
#                                             Unnamed: 0  \
# 0    Nom du Produit en Français (traduction approxi...
# 1               Poulet,  biologique, à la ferme / FR U
# 2    Poulet, biologique, système n ° 1, à la ferme ...
# 3    Poulet, biologique, système n ° 2, à la ferme ...
# 4    poule Réforme, porte biologique, à la ferme / ...
# ..                                                 ...
# 215  Endive, saison, biologique, la production de r...
# 216  Endive, saison, biologique, de stockage et de ...
# 217               Melon, biologique, à la ferme / FR U
# 218  Courge, printemps, sous tunnel, porte biologiq...
# 219  Tomate, biologique, la production à effet de s...
#
#                                             Unnamed: 1  \
# 0                                             LCI Name
# 1                  Broiler, organic, at farm gate/FR U
# 2      Chicken, organic, system n°1, at farm gate/FR U
# 3      Chicken, organic, system n°2, at farm gate/FR U
# ...

# %%
print(df_synthese.shape)
print(df_synthese.describe(include='all'))
# Out:
# (2997, 27)
#        Code AGB   Code CIQUAL         Groupe d'aliment Sous-groupe d'aliment  \
# count      2479   2479.000000                     2479                  2479
# unique     2479           NaN                       11                    58
# top        9690           NaN  viandes, œufs, poissons               légumes
# freq          1           NaN                      636                   196
# mean        NaN  22446.076240                      NaN                   NaN
# std         NaN  14034.948243                      NaN                   NaN
# min         NaN   1000.000000                      NaN                   NaN
# 25%         NaN  12759.500000                      NaN                   NaN
# 50%         NaN  20511.000000                      NaN                   NaN
# 75%         NaN  26105.000000                      NaN                   NaN
# max         NaN  96778.000000                      NaN                   NaN
#
# ...

# %%
#on regarde si le dataframe comportent des "NA"
df_synthese.isnull().sum()
df_detail_ingredient.isnull().sum()
df_détail_etape.isnull().sum()
df_agri1.isnull().sum()
df_agri2.isnull().sum()
# Out:
# Unnamed: 0                                  0
# Unnamed: 1                                  0
# Unnamed: 2                                  0
# Climate change                              2
# Ozone depletion                             2
# Ionising radiation, HH                      2
# Photochemical ozone formation, HH           2
# Respiratory inorganics                      2
# Acidification terrestrial and freshwater    2
# Eutrophication freshwater                   2
# Eutrophication marine                       2
# Eutrophication terrestrial                  2
# Ecotoxicity freshwater                      2
# Land use                                    2
# Water scarcity                              2
# Resource use, energy carriers               2
# Resource use, mineral and metals            2
# Climate change - fossil                     2
# Climate change - biogenic                   2
# Climate change - land use and transform.    2
# dtype: int64

# %%
#on enlève les données manquantes
df_synthese = df_synthese.dropna()
df_detail_etape = df_détail_etape.dropna()
df_agri2 = df_agri2.dropna()

df_synthese
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-563f8546a18b> in <module>
#       2 df_synthese = df_synthese.dropna()
#       3 df_detail_etape = df_détail_etape.dropna()
# ----> 4 df_agri2 = df_agri2.dropna()
#       5
#       6 df_synthese
#
# NameError: name 'df_agri2' is not defined

# %% [markdown]
# 1) Nettoyage du dataframe df_synthèse

# %%
df_synthese.drop(["Code AGB","Groupe d'aliment","Code CIQUAL", "LCI Name"], axis = "columns", inplace = True)
df_synthese = df_synthese.rename(columns={"Sous-groupe d'aliment": "Groupe d'aliment"}) 
df_synthese
# Out:
#      Groupe d'aliment                      Nom du Produit en Français  \
# 0              fruits      Abricot au sirop léger, appertisé, égoutté
# 1              fruits  Abricot au sirop léger, appertisé, non égoutté
# 2              fruits            Abricot au sirop, appertisé, égoutté
# 3              fruits        Abricot au sirop, appertisé, non égoutté
# 4              fruits                         Abricot, dénoyauté, cru
# ...               ...                                             ...
# 2992              NaN                                             NaN
# 2993              NaN                                             NaN
# 2994              NaN                                             NaN
# 2995              NaN                                             NaN
# 2996              NaN                                             NaN
#
#                 Saisonnalité  Transport par avion (1 : par avion)  \
# ...

# %%
#on supprime les aliments ayant un DQR trop élevé (les données recueillies sont peu fiables)
df_synthese = df_synthese[df_synthese["DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)"].between(1,4)]
df_synthese
# Out:
#                           Groupe d'aliment  \
# 0                                   fruits
# 1                                   fruits
# 2                                   fruits
# 3                                   fruits
# 4                                   fruits
# ...                                    ...
# 2474  produits laitiers frais et assimilés
# 2475  produits laitiers frais et assimilés
# 2476  produits laitiers frais et assimilés
# 2477  produits laitiers frais et assimilés
# 2478  produits laitiers frais et assimilés
#
#                              Nom du Produit en Français  \
# 0            Abricot au sirop léger, appertisé, égoutté
# 1        Abricot au sirop léger, appertisé, non égoutté
# 2                  Abricot au sirop, appertisé, égoutté
# 3              Abricot au sirop, appertisé, non égoutté
# 4                               Abricot, dénoyauté, cru
# ...                                                 ...
# ...

# %%
df_synthese_classé = df_synthese.sort_values("Score unique EF (mPt/kg de produit)", ascending=False)
df_synthese_classé
# Out:
#                       Groupe d'aliment  \
# 26                      viandes cuites
# 23                      viandes cuites
# 8                       viandes cuites
# 20                      viandes cuites
# 335   autres produits à base de viande
# ...                                ...
# 2339              boissons sans alcool
# 2340              boissons sans alcool
# 2356              boissons sans alcool
# 2237                            soupes
# 2236                            soupes
#
#                              Nom du Produit en Français  \
# 26    Agneau, selle, partie maigre, rôtie/cuite au four
# 23                     Agneau, gigot, rôti/cuit au four
# 8                    Agneau, collier, braisé ou bouilli
# 20                                Agneau, gigot, braisé
# 335                                  Brochette d'agneau
# ...                                                 ...
# 2339                      Thé oolong, infusé, non sucré
# ...

# %% [markdown]
# 2) Nettoyage du dataframe df_détail_étape

# %% [markdown]
# Le nettoyage est résolument similaire que celui du dataframe df_synthèse. On commence d'abord par enlever les données manquantes et les colonnes redondantes du dataframe

# %%
df_détail_etape = df_détail_etape.dropna()
df_détail_etape.drop(["Code CIQUAL", "LCI Name", "Groupe d'aliment", "Nom et code","DQR - P", "DQR - TiR", "DQR - GR", "DQR - TeR"], axis='columns', inplace=True)
df_détail_etape
# Out:
#      Code AGB                 Sous-groupe d'aliment  \
# 0       12112                              fromages
# 1       13712                                fruits
# 2       13713                                fruits
# 3       13714                                fruits
# 4       13715                                fruits
# ...       ...                                   ...
# 2475    19592  produits laitiers frais et assimilés
# 2476    19593  produits laitiers frais et assimilés
# 2477    19594  produits laitiers frais et assimilés
# 2478    19598  produits laitiers frais et assimilés
# 2479    19599  produits laitiers frais et assimilés
#
#                              Nom du Produit en Français   DQR  \
# 0                                             Abondance  2.24
# 1            Abricot au sirop léger, appertisé, égoutté  2.46
# 2        Abricot au sirop léger, appertisé, non égoutté  2.46
# 3                  Abricot au sirop, appertisé, égoutté  2.46
# ...

# %% [markdown]
# On remarque que les indicateurs précédemment triés se séparent entre six catégories correspondant aux six étapes du cycle de vie des aliments étudiés.
# Afin de pouvoir exploité le dataframe, il serait pratique de regrouper les indicateurs par étape du cycle de vie afin de cibler l'impact de chaque étape sur l'environnement.
# Nous crééons ainsi des indicateurs synthétiques qui réalisent la moyenne pondérée de l'ensemble des indicateurs concernant cette même étape.
# Nous ne conservons ainsi que le dataframe contenant les éléments essentiels de présentation des aliments ainsi que ces indicateurs synthétiques.

# %%
df_détail_etape["Score unique EF (mPt / kg de produit)"] = (df_détail_etape["Score unique EF (mPt / kg de produit) - Agriculture"] + df_détail_etape["Score unique EF (mPt / kg de produit) - Transformation"] + df_détail_etape["Score unique EF (mPt / kg de produit) - Emballage"] + df_détail_etape["Score unique EF (mPt / kg de produit) - Transport"] + df_détail_etape["Score unique EF (mPt / kg de produit) - Supermarché et distribution"] + df_détail_etape["Score unique EF (mPt / kg de produit) - Consommation"])/6
df_détail_etape["impact de l'étape Agriculture"] = (df_détail_etape["Changement climatique (kg CO2 eq/kg de produit) - Agriculture"] + df_détail_etape["Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit) - Agriculture"] + df_détail_etape["Rayonnements ionisants (kBq U-235 eq/kg de produit) - Agriculture"] + df_détail_etape["Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produit) - Agriculture"] + df_détail_etape["Particules (E-06 disease inc./kg de produit) - Agriculture"] + df_détail_etape["Acidification terrestre et eaux douces (mol H+ eq/kg de produit) - Agriculture"] + df_détail_etape["Eutrophisation terreste (mol N eq/kg de produit) - Agriculture"] + df_détail_etape["Eutrophisation eaux douces (E-03 kg P eq/kg de produit) - Agriculture"] + df_détail_etape["Eutrophisation marine (E-03 kg N eq/kg de produit) - Agriculture"] + df_détail_etape["Utilisation du sol (Pt/kg de produit) - Agriculture"] + df_détail_etape["Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit) - Agriculture"] + df_détail_etape["Épuisement des ressources eau (m3 depriv./kg de produit) - Agriculture"] + df_détail_etape["Épuisement des ressources énergétiques (MJ/kg de produit) - Agriculture"] + df_détail_etape["Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Agriculture"])/14
df_détail_etape["impact de l'étape Transformation"] = (df_détail_etape["Changement climatique (kg CO2 eq/kg de produit) - Transformation"] + df_détail_etape["Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit) - Transformation"] + df_détail_etape["Rayonnements ionisants (kBq U-235 eq/kg de produit) - Transformation"] + df_détail_etape["Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produit) - Transformation"] + df_détail_etape["Particules (E-06 disease inc./kg de produit) - Transformation"] + df_détail_etape["Acidification terrestre et eaux douces (mol H+ eq/kg de produit) - Transformation"] + df_détail_etape["Eutrophisation terreste (mol N eq/kg de produit) - Transformation"] + df_détail_etape["Eutrophisation eaux douces (E-03 kg P eq/kg de produit) - Transformation"] + df_détail_etape["Eutrophisation marine (E-03 kg N eq/kg de produit) - Transformation"] + df_détail_etape["Utilisation du sol (Pt/kg de produit) - Transformation"] + df_détail_etape["Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit) - Transformation"] + df_détail_etape["Épuisement des ressources eau (m3 depriv./kg de produit) - Transformation"] + df_détail_etape["Épuisement des ressources énergétiques (MJ/kg de produit) - Transformation"] + df_détail_etape["Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Transformation"])/14
df_détail_etape["impact de l'étape Emballage"] = (df_détail_etape["Changement climatique (kg CO2 eq/kg de produit) - Emballage"] + df_détail_etape["Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit) - Emballage"] + df_détail_etape["Rayonnements ionisants (kBq U-235 eq/kg de produit) - Emballage"] + df_détail_etape["Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produit) - Emballage"] + df_détail_etape["Particules (E-06 disease inc./kg de produit) - Emballage"] + df_détail_etape["Acidification terrestre et eaux douces (mol H+ eq/kg de produit) - Emballage"] + df_détail_etape["Eutrophisation terreste (mol N eq/kg de produit) - Emballage"] + df_détail_etape["Eutrophisation eaux douces (E-03 kg P eq/kg de produit) - Emballage"] + df_détail_etape["Eutrophisation marine (E-03 kg N eq/kg de produit) - Emballage"] + df_détail_etape["Utilisation du sol (Pt/kg de produit) - Emballage"] + df_détail_etape["Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit) - Emballage"] + df_détail_etape["Épuisement des ressources eau (m3 depriv./kg de produit) - Emballage"] + df_détail_etape["Épuisement des ressources énergétiques (MJ/kg de produit) - Emballage"] + df_détail_etape["Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Emballage"])/14
df_détail_etape["impact de l'étape Transport"] = (df_détail_etape["Changement climatique (kg CO2 eq/kg de produit) - Transport"] + df_détail_etape["Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit) - Transport"] + df_détail_etape["Rayonnements ionisants (kBq U-235 eq/kg de produit) - Transport"] + df_détail_etape["Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produit) - Transport"] + df_détail_etape["Particules (E-06 disease inc./kg de produit) - Transport"] + df_détail_etape["Acidification terrestre et eaux douces (mol H+ eq/kg de produit) - Transport"] + df_détail_etape["Eutrophisation terreste (mol N eq/kg de produit) - Transport"] + df_détail_etape["Eutrophisation eaux douces (E-03 kg P eq/kg de produit) - Transport"] + df_détail_etape["Eutrophisation marine (E-03 kg N eq/kg de produit) - Transport"] + df_détail_etape["Utilisation du sol (Pt/kg de produit) - Transport"] + df_détail_etape["Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit) - Transport"] + df_détail_etape["Épuisement des ressources eau (m3 depriv./kg de produit) - Transport"] + df_détail_etape["Épuisement des ressources énergétiques (MJ/kg de produit) - Transport"] + df_détail_etape["Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Transport"])/14
df_détail_etape["impact de l'étape Supermarché et distribution"] = (df_détail_etape["Changement climatique (kg CO2 eq/kg de produit) - Supermarché et distribution"] + df_détail_etape["Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit) - Supermarché et distribution"] + df_détail_etape["Rayonnements ionisants (kBq U-235 eq/kg de produit) - Supermarché et distribution"] + df_détail_etape["Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produit) - Supermarché et distribution"] + df_détail_etape["Particules (E-06 disease inc./kg de produit) - Supermarché et distribution"] + df_détail_etape["Acidification terrestre et eaux douces (mol H+ eq/kg de produit) - Supermarché et distribution"] + df_détail_etape["Eutrophisation terreste (mol N eq/kg de produit) - Supermarché et distribution"] + df_détail_etape["Eutrophisation eaux douces (E-03 kg P eq/kg de produit) - Supermarché et distribution"] + df_détail_etape["Eutrophisation marine (E-03 kg N eq/kg de produit) - Supermarché et distribution"] + df_détail_etape["Utilisation du sol (Pt/kg de produit) - Supermarché et distribution"] + df_détail_etape["Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit) - Supermarché et distribution"] + df_détail_etape["Épuisement des ressources eau (m3 depriv./kg de produit) - Supermarché et distribution"] + df_détail_etape["Épuisement des ressources énergétiques (MJ/kg de produit) - Supermarché et distribution"] + df_détail_etape["Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Supermarché et distribution"])/14
df_détail_etape["impact de l'étape Consommation"] = (df_détail_etape["Changement climatique (kg CO2 eq/kg de produit) - Consommation"] + df_détail_etape["Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit) - Consommation"] + df_détail_etape["Rayonnements ionisants (kBq U-235 eq/kg de produit) - Consommation"] + df_détail_etape["Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produit) - Consommation"] + df_détail_etape["Particules (E-06 disease inc./kg de produit) - Consommation"] + df_détail_etape["Acidification terrestre et eaux douces (mol H+ eq/kg de produit) - Consommation"] + df_détail_etape["Eutrophisation terreste (mol N eq/kg de produit) - Consommation"] + df_détail_etape["Eutrophisation eaux douces (E-03 kg P eq/kg de produit) - Consommation"] + df_détail_etape["Eutrophisation marine (E-03 kg N eq/kg de produit) - Consommation"] + df_détail_etape["Utilisation du sol (Pt/kg de produit) - Consommation"] + df_détail_etape["Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit) - Consommation"] + df_détail_etape["Épuisement des ressources eau (m3 depriv./kg de produit) - Consommation"] + df_détail_etape["Épuisement des ressources énergétiques (MJ/kg de produit) - Consommation"] + df_détail_etape["Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Consommation"])/14

df_détail_etape_synthese = df_détail_etape[["Sous-groupe d'aliment",'Nom du Produit en Français',"DQR","Score unique EF (mPt / kg de produit)", "impact de l'étape Agriculture", "impact de l'étape Transformation", "impact de l'étape Emballage", "impact de l'étape Transport","impact de l'étape Supermarché et distribution", "impact de l'étape Consommation"]]
df_détail_etape_synthese
# Out:
#                      Sous-groupe d'aliment  \
# 0                                 fromages
# 1                                   fruits
# 2                                   fruits
# 3                                   fruits
# 4                                   fruits
# ...                                    ...
# 2475  produits laitiers frais et assimilés
# 2476  produits laitiers frais et assimilés
# 2477  produits laitiers frais et assimilés
# 2478  produits laitiers frais et assimilés
# 2479  produits laitiers frais et assimilés
#
#                              Nom du Produit en Français   DQR  \
# 0                                             Abondance  2.24
# 1            Abricot au sirop léger, appertisé, égoutté  2.46
# 2        Abricot au sirop léger, appertisé, non égoutté  2.46
# 3                  Abricot au sirop, appertisé, égoutté  2.46
# 4              Abricot au sirop, appertisé, non égoutté  2.44
# ...                                                 ...   ...
# ...

# %% [markdown]
# A nouveau, on ne garde que les données qui ont un DQR (data quality ratio) plus faible que 3 (voir supra pour la justification du seuil).

# %%
df_détail_etape_synthese = df_détail_etape_synthese[df_détail_etape_synthese["DQR"]<=3].copy()
df_détail_etape_synthese
# Out:
#                      Sous-groupe d'aliment  \
# 0                                 fromages
# 1                                   fruits
# 2                                   fruits
# 3                                   fruits
# 4                                   fruits
# ...                                    ...
# 2470  produits laitiers frais et assimilés
# 2476  produits laitiers frais et assimilés
# 2477  produits laitiers frais et assimilés
# 2478  produits laitiers frais et assimilés
# 2479  produits laitiers frais et assimilés
#
#                              Nom du Produit en Français   DQR  \
# 0                                             Abondance  2.24
# 1            Abricot au sirop léger, appertisé, égoutté  2.46
# 2        Abricot au sirop léger, appertisé, non égoutté  2.46
# 3                  Abricot au sirop, appertisé, égoutté  2.46
# 4              Abricot au sirop, appertisé, non égoutté  2.44
# ...                                                 ...   ...
# ...

# %% [markdown]
# De même, nous supprimmons les doublons dans les noms des produits afin de conserver qu'une seule ligne par produit de même appelation (on s'assure que chaque produit du tableau a une valeur différente de score unique).

# %%
df_détail_etape_synthese = df_détail_etape_synthese.drop_duplicates(subset = ['Score unique EF (mPt / kg de produit)'])
df_détail_etape_synthese
# Out:
#                      Sous-groupe d'aliment  \
# 0                                 fromages
# 1                                   fruits
# 2                                   fruits
# 5                                   fruits
# 6                                   fruits
# ...                                    ...
# 2467  produits laitiers frais et assimilés
# 2468  produits laitiers frais et assimilés
# 2470  produits laitiers frais et assimilés
# 2478  produits laitiers frais et assimilés
# 2479  produits laitiers frais et assimilés
#
#                              Nom du Produit en Français   DQR  \
# 0                                             Abondance  2.24
# 1            Abricot au sirop léger, appertisé, égoutté  2.46
# 2        Abricot au sirop léger, appertisé, non égoutté  2.46
# 5                               Abricot, dénoyauté, cru  2.20
# 6                               Abricot, dénoyauté, sec  2.64
# ...                                                 ...   ...
# ...

# %% [markdown]
# Finalement, nous classons comme précédemment les données en fonction du sous-groupe d'aliment.

# %%
df_détail_etape_synthese = df_détail_etape_synthese.sort_values("Sous-groupe d'aliment", ascending = True)
df_détail_etape_synthese
# Out:
#         Sous-groupe d'aliment  \
# 1927         aides culinaires
# 1223                   algues
# 8                      algues
# 1276  autres matières grasses
# 1080  autres matières grasses
# ...                       ...
# 1553                     œufs
# 1554                     œufs
# 1555                     œufs
# 1536                     œufs
# 1552                     œufs
#
#                              Nom du Produit en Français   DQR  \
# 1927  Préparation culinaire à base de soja, type "cr...  2.09
# 1223  Kombu ou kombu japonais (Laminaria japonica), ...  2.99
# 8                                     Agar (algue), cru  2.99
# 1276                                     Lard gras, cru  2.11
# 1080                                  Graisse de canard  2.96
# ...                                                 ...   ...
# 1553                           Omelette aux champignons  2.30
# 1554                          Omelette aux fines herbes  2.29
# ...

# %%
df_détail_etape_synthese = df_détail_etape_synthese.reset_index(drop=True)
df_détail_etape_synthese
# Out:
#        Sous-groupe d'aliment  \
# 0           aides culinaires
# 1                     algues
# 2                     algues
# 3    autres matières grasses
# 4    autres matières grasses
# ..                       ...
# 938                     œufs
# 939                     œufs
# 940                     œufs
# 941                     œufs
# 942                     œufs
#
#                             Nom du Produit en Français   DQR  \
# 0    Préparation culinaire à base de soja, type "cr...  2.09
# 1    Kombu ou kombu japonais (Laminaria japonica), ...  2.99
# 2                                    Agar (algue), cru  2.99
# 3                                       Lard gras, cru  2.11
# 4                                    Graisse de canard  2.96
# ..                                                 ...   ...
# 938                           Omelette aux champignons  2.30
# 939                          Omelette aux fines herbes  2.29
# ...
